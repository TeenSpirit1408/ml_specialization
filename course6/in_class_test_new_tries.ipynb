# %%
import pandas as pd
import numpy as np
from sklearn import cross_validation, linear_model, metrics, preprocessing
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn import feature_selection as fs
from sklearn.svm import LinearSVC
# Out:
# C:\Users\yuranich\Anaconda2\lib\site-packages\sklearn\cross_validation.py:44: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %%
train = pd.read_csv("orange_small_churn_train_data.csv", index_col='ID')
y = train['labels']
test = pd.read_csv("orange_small_churn_test_data.csv", index_col='ID')
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40000 entries, 0 to 39999
# Columns: 231 entries, Var1 to labels
# dtypes: float64(191), int64(2), object(38)
# memory usage: 70.8+ MB

# %%
data = pd.concat([train.drop('labels', axis=1), test], ignore_index=True)
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Columns: 230 entries, Var1 to Var230
# dtypes: float64(191), int64(1), object(38)
# memory usage: 87.7+ MB

# %%
numbers = data.ix[:, 0:190]
names_to_drop = []
for name in numbers.columns:
    col = numbers[name].dropna()
    if len(col.unique()) < 2:
        names_to_drop.append(name)

numbers.drop(names_to_drop, axis=1, inplace=True)

# %%
def write_result(result, filename):
    churn_probs = [x[1] for x in result]
    ids = range(len(churn_probs))
    df  = pd.DataFrame(index=ids, data=churn_probs, columns=['result'])
    df.to_csv(filename, index_label = 'Id')

def test_dataset(train, y, test, filename):
    clf = GradientBoostingClassifier(n_estimators=200, random_state=10)
#     clf.fit(train, y)
#     result = clf.predict_proba(test)
#     write_result(result, filename)

# %%
try1 = numbers.copy()
try1.fillna(0, inplace=True)
try1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Columns: 173 entries, Var1 to Var190
# dtypes: float64(172), int64(1)
# memory usage: 66.0 MB

# %%
test_dataset(try1[0:40000], y, try1[40000:], "test1.csv")

# %%
try2 = numbers.copy()
for i in range(try2.shape[1]):
    col = try2.ix[:, i]
    mean = col.mean()
    col.fillna(mean, inplace=True)
try2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Columns: 173 entries, Var1 to Var190
# dtypes: float64(172), int64(1)
# memory usage: 66.0 MB

# %%
test_dataset(try2[0:40000], y, try2[40000:], "test2.csv")

# %%
try1.describe()
# Out:
#                Var1          Var2           Var3          Var4          Var5  \
# count  50000.000000  50000.000000   50000.000000  50000.000000  5.000000e+04
# mean       0.161280      0.000100      10.547400      0.003960  7.101714e+03
# std        5.006245      0.022361     675.452356      0.227652  1.182221e+05
# min        0.000000      0.000000       0.000000      0.000000  0.000000e+00
# 25%        0.000000      0.000000       0.000000      0.000000  0.000000e+00
# 50%        0.000000      0.000000       0.000000      0.000000  0.000000e+00
# 75%        0.000000      0.000000       0.000000      0.000000  0.000000e+00
# max      680.000000      5.000000  130668.000000     27.000000  6.048550e+06
#
#                 Var6         Var7          Var9         Var10         Var11  \
# count   50000.000000  50000.00000  50000.000000  5.000000e+04  50000.000000
# mean     1179.759700      6.05514      0.675960  1.167609e+04      0.213920
# std      2566.782817      6.33667     19.182295  1.733427e+05      1.415471
# min         0.000000      0.00000      0.000000  0.000000e+00      0.000000
# 25%       287.000000      0.00000      0.000000  0.000000e+00      0.000000
# 50%       798.000000      7.00000      0.000000  0.000000e+00      0.000000
# 75%      1316.000000      7.00000      0.000000  0.000000e+00      0.000000
# max    131761.000000    140.00000   2300.000000  1.232559e+07     40.000000
#
#            ...              Var180        Var181        Var182        Var183  \
# count      ...        5.000000e+04  50000.000000  5.000000e+04  5.000000e+04
# mean       ...        5.302563e+04      0.550200  4.473743e+04  1.930346e+03
# std        ...        6.311803e+05      2.374479  4.747742e+05  3.397867e+04
# min        ...        0.000000e+00      0.000000  0.000000e+00  0.000000e+00
# 25%        ...        0.000000e+00      0.000000  0.000000e+00  0.000000e+00
# 50%        ...        0.000000e+00      0.000000  0.000000e+00  0.000000e+00
# 75%        ...        0.000000e+00      0.000000  0.000000e+00  0.000000e+00
# max        ...        1.428483e+07     49.000000  1.199478e+07  3.048400e+06
#
#              Var184        Var186        Var187        Var188        Var189  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean       0.210000      0.046320      0.232280      4.154086    113.578560
# std        7.513715      1.109937      7.391748     31.626171    144.718679
# min        0.000000      0.000000      0.000000     -6.420000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000    246.000000
# max     1200.000000    102.000000    910.000000    628.620000    642.000000
#
#               Var190
# count   50000.000000
# mean      146.566921
# std      2970.063833
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         0.000000
# max    230427.000000
#
# [8 rows x 173 columns]

# %%
scaled1 = (try1 - try1.min()) / (try1.max() - try1.min())
scaled1.describe()
# Out:
#                Var1          Var2          Var3          Var4          Var5  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean       0.000237      0.000020      0.000081      0.000147      0.001174
# std        0.007362      0.004472      0.005169      0.008432      0.019546
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#                Var6          Var7          Var9         Var10         Var11  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean       0.008954      0.043251      0.000294      0.000947      0.005348
# std        0.019481      0.045262      0.008340      0.014064      0.035387
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.002178      0.000000      0.000000      0.000000      0.000000
# 50%        0.006056      0.050000      0.000000      0.000000      0.000000
# 75%        0.009988      0.050000      0.000000      0.000000      0.000000
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#            ...             Var180        Var181        Var182        Var183  \
# count      ...       50000.000000  50000.000000  50000.000000  50000.000000
# mean       ...           0.003712      0.011229      0.003730      0.000633
# std        ...           0.044185      0.048459      0.039582      0.011146
# min        ...           0.000000      0.000000      0.000000      0.000000
# 25%        ...           0.000000      0.000000      0.000000      0.000000
# 50%        ...           0.000000      0.000000      0.000000      0.000000
# 75%        ...           0.000000      0.000000      0.000000      0.000000
# max        ...           1.000000      1.000000      1.000000      1.000000
#
#              Var184        Var186        Var187        Var188        Var189  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean       0.000175      0.000454      0.000255      0.016651      0.176914
# std        0.006261      0.010882      0.008123      0.049802      0.225419
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.010110      0.000000
# 50%        0.000000      0.000000      0.000000      0.010110      0.000000
# 75%        0.000000      0.000000      0.000000      0.010110      0.383178
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#              Var190
# count  50000.000000
# mean       0.000636
# std        0.012889
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        0.000000
# max        1.000000
#
# [8 rows x 173 columns]

# %%
scaled2 = (try2 - try2.min()) / (try2.max() - try2.min())
scaled2.describe()
# Out:
#                Var1          Var2          Var3          Var4          Var5  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean       0.016893      0.000806      0.003255      0.004644      0.039479
# std        0.007089      0.004470      0.005144      0.008392      0.018359
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.016893      0.000806      0.003255      0.004644      0.039479
# 50%        0.016893      0.000806      0.003255      0.004644      0.039479
# 75%        0.016893      0.000806      0.003255      0.004644      0.039479
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#                Var6          Var7          Var9         Var10         Var11  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean       0.010067      0.048639      0.020933      0.031853      0.019556
# std        0.019223      0.042610      0.007968      0.012981      0.014116
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.004409      0.000000      0.020933      0.031853      0.019556
# 50%        0.007172      0.050000      0.020933      0.031853      0.019556
# 75%        0.010067      0.050000      0.020933      0.031853      0.019556
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#            ...             Var180        Var181        Var182        Var183  \
# count      ...       50000.000000  50000.000000  50000.000000  50000.000000
# mean       ...           0.264389      0.012479      0.118105      0.025513
# std        ...           0.031380      0.048314      0.033766      0.010416
# min        ...           0.000000      0.000000      0.000000      0.000000
# 25%        ...           0.264389      0.000000      0.118105      0.025513
# 50%        ...           0.264389      0.000000      0.118105      0.025513
# 75%        ...           0.264389      0.000000      0.118105      0.025513
# max        ...           1.000000      1.000000      1.000000      1.000000
#
#              Var184        Var186        Var187        Var188        Var189  \
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean       0.007051      0.032345      0.018180      0.273665      0.415318
# std        0.006165      0.010195      0.007836      0.028266      0.088399
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.007051      0.032345      0.018180      0.273665      0.415318
# 50%        0.007051      0.032345      0.018180      0.273665      0.415318
# 75%        0.007051      0.032345      0.018180      0.273665      0.415318
# max        1.000000      1.000000      1.000000      1.000000      1.000000
#
#              Var190
# count  50000.000000
# mean       0.095505
# std        0.010286
# min        0.000000
# 25%        0.095505
# 50%        0.095505
# 75%        0.095505
# max        1.000000
#
# [8 rows x 173 columns]

# %%
test_dataset(scaled1[0:40000], y, scaled1[40000:], "test3.csv")
test_dataset(scaled2[0:40000], y, scaled2[40000:], "test4.csv")

# %%
categors = data.ix[:, 190:230]
names_to_drop = []
for name in categors.columns:
    col = categors[name].dropna()
    if len(col.unique()) < 2:
        names_to_drop.append(name)

categors.drop(names_to_drop, axis=1, inplace=True)

categors.fillna(method='bfill', inplace=True)
categors.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 34 columns):
# Var192    50000 non-null object
# Var193    50000 non-null object
# Var194    49995 non-null object
# Var195    50000 non-null object
# Var196    50000 non-null object
# Var197    50000 non-null object
# Var198    50000 non-null object
# Var199    50000 non-null object
# Var200    50000 non-null object
# Var201    49995 non-null object
# Var202    50000 non-null object
# Var203    50000 non-null object
# Var204    50000 non-null object
# Var205    50000 non-null object
# Var206    50000 non-null object
# Var207    50000 non-null object
# Var208    50000 non-null object
# Var210    50000 non-null object
# Var211    50000 non-null object
# Var212    50000 non-null object
# Var214    50000 non-null object
# Var216    50000 non-null object
# Var217    50000 non-null object
# Var218    50000 non-null object
# Var219    50000 non-null object
# Var220    50000 non-null object
# Var221    50000 non-null object
# Var222    50000 non-null object
# Var223    50000 non-null object
# Var225    49998 non-null object
# Var226    50000 non-null object
# Var227    50000 non-null object
# Var228    50000 non-null object
# Var229    50000 non-null object
# dtypes: object(34)
# memory usage: 13.0+ MB

# %%
#преобразуем все признаки в числовые
le = preprocessing.LabelEncoder()
cat_as_nums = categors.apply(le.fit_transform)
cat_as_nums.head()
# Out:
# C:\Users\yuranich\Anaconda2\lib\site-packages\numpy\lib\arraysetops.py:200: FutureWarning: numpy not_equal will not check object identity in the future. The comparison did not return the same result as suggested by the identity (`is`)) and will change.
#   flag = np.concatenate(([True], aux[1:] != aux[:-1]))
#    Var192  Var193  Var194  Var195  Var196  Var197  Var198  Var199  Var200  \
# 0     161       5       2      22       0       0    2169    1447    3511
# 1     170       0       2      22       0     129     830    4076    3511
# 2     115      17       2      22       0     113    2991    4015   10529
# 3     333      25       2      22       0       2    4000    1804   10529
# 4      38      25       2      22       0     210    3331    2897   10529
#
#    Var201   ...    Var219  Var220  Var221  Var222  Var223  Var225  Var226  \
# 0       2   ...        11    3129       0    4067       0       1      14
# 1       2   ...        11    3138       4     379       0       1      22
# 2       2   ...        11     350       6    2751       0       1       7
# 3       2   ...        11    4232       4    2864       0       1      22
# 4       2   ...        11    1797       4    1506       0       1      12
#
#    Var227  Var228  Var229
# 0       0      29       1
# 1       2       2       1
# 2       3      25       1
# 3       2       8       0
# 4       2       8       0
#
# [5 rows x 34 columns]

# %%
nums1 = pd.concat([scaled1, cat_as_nums], axis=1)

cat_scaled = (cat_as_nums - cat_as_nums.min()) / (cat_as_nums.max() - cat_as_nums.min())
nums2 = pd.concat([scaled1, cat_scaled], axis=1)
nums2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Columns: 207 entries, Var1 to Var229
# dtypes: float64(207)
# memory usage: 79.0 MB

# %%
test_dataset(nums1[0:40000], y, nums1[40000:], "test5.csv")
test_dataset(nums2[0:40000], y, nums2[40000:], "test6.csv")

# %%
nums2.to_csv("data_prepared.csv", index_label = 'Id')

# %%
from imblearn import under_sampling as us

# %%
sampler = us.ClusterCentroids(random_state=10)
X_res2, y_res2 = sampler.fit_sample(nums2[0:40000], y)
(len(X_res2), len(y_res2))
# Out:
# (5952, 5952)

# %%
test_dataset(X_res2, y_res2, nums2[40000:], "test7.csv")

# %%
sfm = fs.SelectFromModel(LinearSVC(penalty="l1", dual=False))
X = sfm.fit_transform(nums2[0:40000], y)
X.shape
# Out:
# (40000, 98)

# %%
selected = nums2.ix[:, sfm.get_support()]
selected.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 50000 entries, 0 to 49999
# Data columns (total 98 columns):
# Var5      50000 non-null float64
# Var6      50000 non-null float64
# Var7      50000 non-null float64
# Var11     50000 non-null float64
# Var14     50000 non-null float64
# Var16     50000 non-null float64
# Var19     50000 non-null float64
# Var24     50000 non-null float64
# Var27     50000 non-null float64
# Var33     50000 non-null float64
# Var34     50000 non-null float64
# Var35     50000 non-null float64
# Var38     50000 non-null float64
# Var50     50000 non-null float64
# Var51     50000 non-null float64
# Var53     50000 non-null float64
# Var54     50000 non-null float64
# Var57     50000 non-null float64
# Var59     50000 non-null float64
# Var65     50000 non-null float64
# Var72     50000 non-null float64
# Var73     50000 non-null float64
# Var76     50000 non-null float64
# Var77     50000 non-null float64
# Var78     50000 non-null float64
# Var80     50000 non-null float64
# Var81     50000 non-null float64
# Var82     50000 non-null float64
# Var83     50000 non-null float64
# Var86     50000 non-null float64
# Var87     50000 non-null float64
# Var93     50000 non-null float64
# Var94     50000 non-null float64
# Var100    50000 non-null float64
# Var102    50000 non-null float64
# Var111    50000 non-null float64
# Var112    50000 non-null float64
# Var113    50000 non-null float64
# Var114    50000 non-null float64
# Var122    50000 non-null float64
# Var123    50000 non-null float64
# Var124    50000 non-null float64
# Var125    50000 non-null float64
# Var126    50000 non-null float64
# Var130    50000 non-null float64
# Var131    50000 non-null float64
# Var133    50000 non-null float64
# Var134    50000 non-null float64
# Var135    50000 non-null float64
# Var136    50000 non-null float64
# Var139    50000 non-null float64
# Var142    50000 non-null float64
# Var143    50000 non-null float64
# Var144    50000 non-null float64
# Var147    50000 non-null float64
# Var149    50000 non-null float64
# Var150    50000 non-null float64
# Var152    50000 non-null float64
# Var153    50000 non-null float64
# Var160    50000 non-null float64
# Var168    50000 non-null float64
# Var173    50000 non-null float64
# Var177    50000 non-null float64
# Var180    50000 non-null float64
# Var181    50000 non-null float64
# Var188    50000 non-null float64
# Var189    50000 non-null float64
# Var192    50000 non-null float64
# Var193    50000 non-null float64
# Var194    50000 non-null float64
# Var196    50000 non-null float64
# Var197    50000 non-null float64
# Var199    50000 non-null float64
# Var200    50000 non-null float64
# Var201    50000 non-null float64
# Var202    50000 non-null float64
# Var203    50000 non-null float64
# Var204    50000 non-null float64
# Var205    50000 non-null float64
# Var206    50000 non-null float64
# Var207    50000 non-null float64
# Var208    50000 non-null float64
# Var210    50000 non-null float64
# Var211    50000 non-null float64
# Var212    50000 non-null float64
# Var214    50000 non-null float64
# Var216    50000 non-null float64
# Var217    50000 non-null float64
# Var218    50000 non-null float64
# Var219    50000 non-null float64
# Var220    50000 non-null float64
# Var222    50000 non-null float64
# Var223    50000 non-null float64
# Var225    50000 non-null float64
# Var226    50000 non-null float64
# Var227    50000 non-null float64
# Var228    50000 non-null float64
# Var229    50000 non-null float64
# dtypes: float64(98)
# memory usage: 37.8 MB

# %%
test_dataset(selected[0:40000], y, selected[40000:], "test8.csv")

# %%
clf = GradientBoostingClassifier(n_estimators=300, learning_rate=0.2, max_depth=5, loss='exponential', max_features=0.3, random_state=10)
clf.fit(nums2[0:40000], y)
result = clf.predict_proba(nums2[40000:])
write_result(result, "test9.csv")

# %%
clf = GradientBoostingClassifier(n_estimators=1000, learning_rate=0.1, random_state=10)
clf.fit(nums2[0:40000], y)
result = clf.predict_proba(nums2[40000:])
write_result(result, "test10.csv")

# %%
clf = RandomForestClassifier(class_weight={1: 5}, criterion='entropy', max_features=0.3, min_samples_leaf=20, n_estimators=200, n_jobs=4, random_state=10)
clf.fit(nums2[0:40000], y)
result = clf.predict_proba(nums2[40000:])
write_result(result, "test11.csv")

# %%
clf = RandomForestClassifier(class_weight={1: 40}, n_estimators=1000, n_jobs=4, random_state=10)
clf.fit(nums2[0:40000], y)
result = clf.predict_proba(nums2[40000:])
write_result(result, "test12.csv")

# %%
clf = GradientBoostingClassifier(n_estimators=200, random_state=10)
clf.fit(nums2[0:40000], y)
result = clf.predict_proba(nums2[40000:])
write_result(result, "test13.csv")
